# %% [markdown]
# ## Wczytanie zbioru danych

# %%
import pandas as pd

data = pd.read_csv('diabetes.csv')

# %% [markdown]
# ## Wypisanie pierwszych 5 wierszy

# %%
data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6    148.0           72.0           35.0      0.0  33.6
# 1            1     85.0           66.0           29.0      0.0  26.6
# 2            8    183.0           64.0            0.0      0.0  23.3
# 3            1     89.0           66.0           23.0     94.0  28.1
# 4            0    137.0           40.0           35.0    168.0  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %% [markdown]
# ## Wyświetlenie podstawowych statystyk i informacji

# %%
data.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   777.000000  774.000000     774.000000     775.000000  775.000000
# mean      3.837838  120.846253      69.113695      20.482581   79.550968
# std       3.367057   31.901991      19.306006      15.935574  115.304169
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   25.000000
# 75%       6.000000  140.000000      80.000000      32.000000  126.000000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  776.000000                772.000000  777.000000  777.000000
# mean    31.935696                  0.471079   33.216216    0.346203
# std      7.933717                  0.329928   11.753683    0.476065
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 777 entries, 0 to 776
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               777 non-null    int64
#  1   Glucose                   774 non-null    float64
#  2   BloodPressure             774 non-null    float64
#  3   SkinThickness             775 non-null    float64
#  4   Insulin                   775 non-null    float64
#  5   BMI                       776 non-null    float64
#  6   DiabetesPedigreeFunction  772 non-null    float64
#  7   Age                       777 non-null    int64
#  8   Outcome                   777 non-null    int64
# dtypes: float64(6), int64(3)
# memory usage: 54.8 KB

# %%
data.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %% [markdown]
# ## Transponowanie

# %%
data.T
# Out:
#                               0       1        2       3        4        5    \
# Pregnancies                 6.000   1.000    8.000   1.000    0.000    5.000
# Glucose                   148.000  85.000  183.000  89.000  137.000  116.000
# BloodPressure              72.000  66.000   64.000  66.000   40.000   74.000
# SkinThickness              35.000  29.000    0.000  23.000   35.000    0.000
# Insulin                     0.000   0.000    0.000  94.000  168.000    0.000
# BMI                        33.600  26.600   23.300  28.100   43.100   25.600
# DiabetesPedigreeFunction    0.627   0.351    0.672   0.167    2.288    0.201
# Age                        50.000  31.000   32.000  21.000   33.000   30.000
# Outcome                     1.000   0.000    1.000   0.000    1.000    0.000
#
#                              6        7        8        9    ...     767  \
# Pregnancies                3.000   10.000    2.000    8.000  ...   1.000
# ...

# %% [markdown]
# ## Sortowanie

# %%
data.sort_values("BMI")
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 776            0    102.0           75.0           23.0      0.0   0.0
# 494            3     80.0            0.0            0.0      0.0   0.0
# 49             7    105.0            0.0            0.0      0.0   0.0
# 81             2     74.0            0.0            0.0      0.0   0.0
# 684            5    136.0           82.0            0.0      0.0   0.0
# ..           ...      ...            ...            ...      ...   ...
# 125            1     88.0           30.0           42.0     99.0  55.0
# 673            3    123.0          100.0           35.0    240.0  57.3
# 445            0    180.0           78.0           63.0     14.0  59.4
# 177            0    129.0          110.0           46.0    130.0  67.1
# 18             1    103.0           30.0           38.0     83.0   NaN
#
#      DiabetesPedigreeFunction  Age  Outcome
# 776                     0.572   21        0
# ...

# %% [markdown]
# ## Obliczenia mody

# %%
data.mode()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0          1.0    100.0           70.0            0.0      0.0  31.2
# 1          NaN      NaN            NaN            NaN      NaN  32.0
#
#    DiabetesPedigreeFunction   Age  Outcome
# 0                     0.254  22.0      0.0
# 1                     0.268   NaN      NaN

# %% [markdown]
# ## Obliczanie mediany

# %%
data.median()
# Out:
# Pregnancies                   3.0000
# Glucose                     117.0000
# BloodPressure                72.0000
# SkinThickness                23.0000
# Insulin                      25.0000
# BMI                          32.0000
# DiabetesPedigreeFunction      0.3725
# Age                          29.0000
# Outcome                       0.0000
# dtype: float64

# %% [markdown]
# ## Obliczanie korelacji

# %%
corr = data.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_60ad5_row0_col0, #T_60ad5_row1_col1, #T_60ad5_row2_col2, #T_60ad5_row3_col3, #T_60ad5_row4_col4, #T_60ad5_row5_col5, #T_60ad5_row6_col6, #T_60ad5_row7_col7, #T_60ad5_row8_col8 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_60ad5_row0_col1, #T_60ad5_row2_col6 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_60ad5_row0_col2, #T_60ad5_row5_col0 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_60ad5_row0_col3 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_60ad5_row0_col4, #T_60ad5_row0_col5, #T_60ad5_row0_col6, #T_60ad5_row2_col8, #T_60ad5_row3_col0, #T_60ad5_row3_col1, #T_60ad5_row3_col7, #T_60ad5_row6_col2, #T_60ad5_row7_col3 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_60ad5_row0_col7 {
#   background-color: #f1cdba;
#   color: #000000;
# }
# #T_60ad5_row0_col8 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_60ad5_row1_col0 {
#   background-color: #7a9df8;
# ...

# %% [markdown]
# ## Operacje na wierszach i kolumnach

# %% [markdown]
# ### wyświetlenie wszystkich wierszy począwszy od 200

# %%
data[200:]
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 200            0    113.0           80.0           16.0      0.0  31.0
# 201            1    138.0           82.0            0.0      0.0  40.1
# 202            0    108.0           68.0           20.0      0.0  27.3
# 203            2     99.0           70.0           16.0     44.0  20.4
# 204            6    103.0           72.0           32.0    190.0  37.7
# ..           ...      ...            ...            ...      ...   ...
# 772            5    106.0           82.0           30.0      0.0  39.5
# 773            2    108.0           52.0           26.0     63.0  32.5
# 774           10    108.0           66.0            0.0      0.0  32.4
# 775            4    154.0           62.0            NaN    284.0  32.8
# 776            0    102.0           75.0           23.0      0.0   0.0
#
#      DiabetesPedigreeFunction  Age  Outcome
# 200                     0.874   21        0
# ...

# %% [markdown]
# ### Wyświetlenie wierszy od początku do 20

# %%
data[:20]
# Out:
#     Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0             6    148.0           72.0           35.0      0.0  33.6
# 1             1     85.0           66.0           29.0      0.0  26.6
# 2             8    183.0           64.0            0.0      0.0  23.3
# 3             1     89.0           66.0           23.0     94.0  28.1
# 4             0    137.0           40.0           35.0    168.0  43.1
# 5             5    116.0           74.0            0.0      0.0  25.6
# 6             3     78.0           50.0           32.0     88.0  31.0
# 7            10    115.0            0.0            0.0      0.0  35.3
# 8             2    197.0           70.0           45.0    543.0  30.5
# 9             8    125.0           96.0            0.0      0.0   0.0
# 10            4    110.0           92.0            0.0      0.0  37.6
# 11           10    168.0           74.0            0.0      0.0  38.0
# ...

# %% [markdown]
# ### Wyświetlenie wierszy od 20 do 25

# %%
data[20:25]
# Out:
#     Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 20            3    126.0           88.0           41.0    235.0  39.3
# 21            8      NaN           84.0            0.0      0.0  35.4
# 22            7    196.0           90.0            0.0      0.0  39.8
# 23            9    119.0           80.0           35.0      0.0  29.0
# 24           11    143.0           94.0           33.0    146.0  36.6
#
#     DiabetesPedigreeFunction  Age  Outcome
# 20                     0.704   27        0
# 21                     0.388   50        0
# 22                     0.451   41        1
# 23                     0.263   29        1
# 24                     0.254   51        1

# %% [markdown]
# ### Pobranie kolumny 3, 4 i 5

# %%
data.iloc[:,3:5]
# Out:
#      SkinThickness  Insulin
# 0             35.0      0.0
# 1             29.0      0.0
# 2              0.0      0.0
# 3             23.0     94.0
# 4             35.0    168.0
# ..             ...      ...
# 772           30.0      0.0
# 773           26.0     63.0
# 774            0.0      0.0
# 775            NaN    284.0
# 776           23.0      0.0
#
# [777 rows x 2 columns]

# %%
data['SkinThickness']
# Out:
# 0      35.0
# 1      29.0
# 2       0.0
# 3      23.0
# 4      35.0
#        ...
# 772    30.0
# 773    26.0
# 774     0.0
# 775     NaN
# 776    23.0
# Name: SkinThickness, Length: 777, dtype: float64

# %% [markdown]
# ### Pobranie wierszy 20 do 25, dla kolumny 3, 4 i 5

# %%
data.iloc[20:25,3:5]
# Out:
#     SkinThickness  Insulin
# 20           41.0    235.0
# 21            0.0      0.0
# 22            0.0      0.0
# 23           35.0      0.0
# 24           33.0    146.0

# %% [markdown]
# ### Pobranie kolumn z wyjątkiem 5-ciu ostatnich

# %%
data.iloc[:,:-5]
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness
# 0              6    148.0           72.0           35.0
# 1              1     85.0           66.0           29.0
# 2              8    183.0           64.0            0.0
# 3              1     89.0           66.0           23.0
# 4              0    137.0           40.0           35.0
# ..           ...      ...            ...            ...
# 772            5    106.0           82.0           30.0
# 773            2    108.0           52.0           26.0
# 774           10    108.0           66.0            0.0
# 775            4    154.0           62.0            NaN
# 776            0    102.0           75.0           23.0
#
# [777 rows x 4 columns]

# %% [markdown]
# ### Usunięcie kolumny BMI

# %%
data.drop(['BMI'], axis = 1).head()
#data.drop(['BMI'], axis = 1, inplace = True)
#data = data.drop(['BMI'], axis = 1)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin  \
# 0            6    148.0           72.0           35.0      0.0
# 1            1     85.0           66.0           29.0      0.0
# 2            8    183.0           64.0            0.0      0.0
# 3            1     89.0           66.0           23.0     94.0
# 4            0    137.0           40.0           35.0    168.0
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %% [markdown]
# ## Warunkowe pobieranie danych

# %%
data[data['BMI'] > 45].sort_values('BMI')
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 229            0    117.0           80.0           31.0     53.0  45.2
# 596            0     67.0           76.0            0.0      0.0  45.3
# 531            0    107.0           76.0            0.0      0.0  45.3
# 420            1    119.0           88.0           41.0    170.0  45.3
# 43             9    171.0          110.0           24.0    240.0  45.4
# 328            2    102.0           86.0           36.0    120.0  45.5
# 270           10    101.0           86.0           37.0      0.0  45.6
# 287            1    119.0           86.0           39.0    220.0  45.6
# 391            5    166.0           76.0            0.0      0.0  45.7
# 16             0    118.0           84.0           47.0      NaN  45.8
# 469            6    154.0           78.0           41.0    140.0  46.1
# 689            1    144.0           82.0           46.0    180.0  46.1
# ...

# %% [markdown]
# ## Wykres liniowy

# %%
data.iloc[:300,]['Glucose'].plot(figsize=(20,20))
# Out:
# <Axes: >

# %% [markdown]
# ## Wykres słupkowy

# %%
data.iloc[0:100,3:6].plot.bar(figsize=(20,20))
# Out:
# <Axes: >

# %% [markdown]
# ## Historgramy

# %%
data.hist(figsize=(20,20))
# Out:
# array([[<Axes: title={'center': 'Pregnancies'}>,
#         <Axes: title={'center': 'Glucose'}>,
#         <Axes: title={'center': 'BloodPressure'}>],
#        [<Axes: title={'center': 'SkinThickness'}>,
#         <Axes: title={'center': 'Insulin'}>,
#         <Axes: title={'center': 'BMI'}>],
#        [<Axes: title={'center': 'DiabetesPedigreeFunction'}>,
#         <Axes: title={'center': 'Age'}>,
#         <Axes: title={'center': 'Outcome'}>]], dtype=object)

# %%
data.iloc[:,2:4].plot.hist(stacked=True, figsize=(20,20))
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# ## Box plot

# %%
data.boxplot(figsize=(20, 20))
# Out:
# <Axes: >

# %% [markdown]
# ## Analiza brakujących danych

# %%
data.isna()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin    BMI  \
# 0          False    False          False          False    False  False
# 1          False    False          False          False    False  False
# 2          False    False          False          False    False  False
# 3          False    False          False          False    False  False
# 4          False    False          False          False    False  False
# ..           ...      ...            ...            ...      ...    ...
# 772        False    False          False          False    False  False
# 773        False    False          False          False    False  False
# 774        False    False          False          False    False  False
# 775        False    False          False           True    False  False
# 776        False    False          False          False    False  False
#
#      DiabetesPedigreeFunction    Age  Outcome
# 0                       False  False    False
# ...

# %% [markdown]
# ## Usunięcie obeserwacji NAN

# %%
data.dropna()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6    148.0           72.0           35.0      0.0  33.6
# 1              1     85.0           66.0           29.0      0.0  26.6
# 2              8    183.0           64.0            0.0      0.0  23.3
# 3              1     89.0           66.0           23.0     94.0  28.1
# 4              0    137.0           40.0           35.0    168.0  43.1
# ..           ...      ...            ...            ...      ...   ...
# 771            3    128.0           78.0            0.0      0.0  21.1
# 772            5    106.0           82.0           30.0      0.0  39.5
# 773            2    108.0           52.0           26.0     63.0  32.5
# 774           10    108.0           66.0            0.0      0.0  32.4
# 776            0    102.0           75.0           23.0      0.0   0.0
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %% [markdown]
# ## Zastąpienie NAN zerami

# %%
data.fillna(0)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6    148.0           72.0           35.0      0.0  33.6
# 1              1     85.0           66.0           29.0      0.0  26.6
# 2              8    183.0           64.0            0.0      0.0  23.3
# 3              1     89.0           66.0           23.0     94.0  28.1
# 4              0    137.0           40.0           35.0    168.0  43.1
# ..           ...      ...            ...            ...      ...   ...
# 772            5    106.0           82.0           30.0      0.0  39.5
# 773            2    108.0           52.0           26.0     63.0  32.5
# 774           10    108.0           66.0            0.0      0.0  32.4
# 775            4    154.0           62.0            0.0    284.0  32.8
# 776            0    102.0           75.0           23.0      0.0   0.0
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...
